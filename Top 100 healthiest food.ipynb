# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()

# %%
df=pd.read_csv("Top 100 healthiest nutrition and protien food.csv")

# %%
df.isnull().sum()
# Out:
# Food                          0
# Nutrition Value (per 100g)    0
# Quantity                      0
# Originated From               0
# Calories                      0
# Protein (g)                   0
# Fiber (g)                     0
# Vitamin C (mg)                0
# Antioxidant Score             0
# dtype: int64

# %%
df
# Out:
#               Food          Nutrition Value (per 100g)         Quantity  \
# 0             Kale            High in Vitamins A, C, K   1 cup, chopped
# 1      Blueberries                High in Antioxidants            1 cup
# 2           Salmon         Rich in Omega-3 Fatty Acids             3 oz
# 3           Garlic                    Contains Allicin          1 clove
# 4          Spinach             High in Iron and Folate       1 cup, raw
# ..             ...                                 ...              ...
# 93          Pomelo                   High in Vitamin C  1 cup, sections
# 94       Radicchio  Low in Calories, High in Vitamin K  1 cup, shredded
# 95          Jicama            Good Source of Vitamin C    1 cup, sliced
# 96  Wakame Seaweed                 High in Fucoxanthin       1 cup, raw
# 97    Dragon Fruit         Good Source of Antioxidants     1 cup, cubed
#
#           Originated From  Calories  Protein (g)  Fiber (g)  Vitamin C (mg)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Food                        98 non-null     object
#  1   Nutrition Value (per 100g)  98 non-null     object
#  2   Quantity                    98 non-null     object
#  3   Originated From             98 non-null     object
#  4   Calories                    98 non-null     int64
#  5   Protein (g)                 98 non-null     float64
#  6   Fiber (g)                   98 non-null     float64
#  7   Vitamin C (mg)              98 non-null     float64
#  8   Antioxidant Score           98 non-null     int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 7.0+ KB

# %%
snr.catplot(x="Food",y="Calories",data=df,hue="Calories")

# %%
df["Food"].unique()
# Out:
# array(['Kale', 'Blueberries', 'Salmon', 'Garlic', 'Spinach', 'Almonds',
#        'Broccoli', 'Avocado', 'Quinoa', 'Lentils', 'Sweet Potato',
#        'Green Tea', 'Turmeric', 'Eggs', 'Chia Seeds', 'Greek Yogurt',
#        'Pomegranate', 'Walnuts', 'Ginger', 'Olive Oil', 'Beets',
#        'Sardines', 'Mushrooms', 'Tomatoes', 'Oats', 'Flaxseeds',
#        'Brussels Sprouts', 'Pumpkin Seeds', 'Black Beans', 'Green Peas',
#        'Asparagus', 'Blackberries', 'Wild Rice', 'Seaweed', 'Cauliflower',
#        'Coconut Oil', 'Red Bell Peppers', 'Watercress', 'Artichokes',
#        'Cherries', 'Mango', 'Pistachios', 'Kiwi', 'Oranges', 'Chickpeas',
#        'Papaya', 'Cabbage', 'Brazil Nuts', 'Cantaloupe', 'Edamame',
#        'Apples', 'Brown Rice', 'Figs', 'Turnips', 'Hemp Seeds',
#        'Butternut Squash', 'Red Grapes', 'Pineapple', 'Collard Greens',
#        'Sunflower Seeds', 'Raspberries', 'Clams', 'Grapefruit',
#        'Kidney Beans', 'Lemons', 'Arugula', 'Onions', 'Zucchini',
# ...

# %%
df["Food"]=label_encoder.fit_transform(df["Food"])
df["Food"].unique()
# Out:
# array([47, 10, 78, 39, 82,  1, 13,  6, 72, 52, 84, 44, 90, 35, 23, 42, 69,
#        93, 40, 61,  7, 79, 56, 88, 60, 38, 15, 71,  8, 43,  5,  9, 96, 81,
#        19, 27, 76, 94,  3, 22, 54, 68, 49, 63, 24, 64, 17, 12, 18, 33,  2,
#        14, 37, 91, 45, 16, 77, 67, 28, 83, 75, 26, 41, 48, 51,  4, 62, 97,
#        53,  0, 31, 66, 34, 65, 20, 95, 74, 11, 89, 30, 29, 86, 25, 55, 57,
#        21, 36, 50, 58, 80, 87, 85, 59, 70, 73, 46, 92, 32])

# %%
df["Nutrition Value (per 100g)"].unique()
# Out:
# array(['High in Vitamins A, C, K', 'High in Antioxidants',
#        'Rich in Omega-3 Fatty Acids', 'Contains Allicin',
#        'High in Iron and Folate', 'Good Source of Vitamin E',
#        'High in Vitamin C and K', 'Rich in Healthy Fats',
#        'Complete Protein Source', 'High in Protein and Fiber',
#        'Rich in Beta-Carotene', 'High in Catechins', 'Contains Curcumin',
#        'High in Omega-3 and Fiber', 'High in Protein and Probiotics',
#        'Rich in Antioxidants', 'Good Source of Omega-3',
#        'Anti-inflammatory Properties', 'Rich in Monounsaturated Fats',
#        'High in Nitrates', 'Rich in Omega-3 and Vitamin D',
#        'Good Source of Selenium', 'High in Lycopene',
#        'Rich in Beta-Glucan', 'High in Lignans', 'High in Vitamin K',
#        'Rich in Magnesium', 'High in Fiber and Protein',
#        'Good Source of Vitamin K', 'High in Folate', 'Rich in Iodine',
#        'Low in Calories, High in Nutrients',
# ...

# %%
df["Nutrition Value (per 100g)"]=label_encoder.fit_transform(df["Nutrition Value (per 100g)"])
df["Nutrition Value (per 100g)"].unique()
# Out:
# array([54, 26, 68,  2, 34, 23, 49, 64,  1, 41, 62, 28,  5, 39, 43, 61, 18,
#         0, 67, 38, 69, 20, 36, 63, 35, 51, 66, 31, 24, 32, 65, 56,  6, 48,
#        30,  7, 45, 21, 72,  8, 58, 44, 19, 71, 16, 27, 57, 11, 10,  3, 50,
#        29, 47, 37, 17,  9, 25, 59, 14, 55,  4, 46, 42, 40, 15, 60, 70, 22,
#        52, 53, 13, 33, 12])

# %%
df["Quantity"].unique()
# Out:
# array(['1 cup, chopped', '1 cup', '3 oz', '1 clove', '1 cup, raw',
#        '1 oz (23 nuts)', '1 medium', '1 cup, cooked', '1 cup, brewed',
#        '1 tsp, ground', '1 large', '1 oz', '6 oz', '1 oz (14 halves)',
#        '1 tbsp, grated', '1 tbsp', '3.75 oz, canned', '1 tbsp, ground',
#        '1 sheet, nori', '1 cup, with pits', '1 cup, sliced',
#        '1 oz (49 kernels)', '1 cup, cubed', '1 oz (6-8 nuts)',
#        '1 cup, shelled', '3 tbsp', '1 cup, chunks', '1/2 medium',
#        '2 cups', '3 oz, cooked', '100g, pulp', '1/4 cup, chopped',
#        '1 cup, diced', '1 cup, shredded', '3 oz, canned in water',
#        '1 cup, whole', '1/4 cup', '1/2 cup', '1 cup, sections'],
#       dtype=object)

# %%
df["Quantity"]=label_encoder.fit_transform(df["Quantity"])
df["Quantity"].unique()
# Out:
# array([ 3,  1, 33,  0,  8, 19, 16,  5,  2, 26, 15, 17, 38, 18, 24, 23, 37,
#        25, 22, 14, 12, 20,  6, 21, 10, 36,  4, 28, 32, 35, 31, 30,  7, 11,
#        34, 13, 29, 27,  9])

# %%
df["Originated From"].unique()
# Out:
# array(['Ancient Greece', 'North America', 'North Pacific Ocean',
#        'Central Asia', 'Ancient Persia', 'Middle East', 'Italy',
#        'Central America', 'South America', 'Central/South America',
#        'China', 'India', 'Worldwide', 'Greece', 'Southeast Asia',
#        'Mediterranean Region', 'Mediterranean Sea', 'Europe',
#        'Ancient Rome', 'Eastern Mediterranean', 'Japan', 'Cyprus',
#        'Asia Minor', 'South Asia', 'Middle East/Africa', 'East Asia',
#        'Asia', 'Western Asia', 'Europe/West Asia', 'Northern Europe/Asia',
#        'Caribbean', 'Africa', 'Europe/North America', 'Sri Lanka',
#        'Northern Europe', 'Indonesia', 'Mexico'], dtype=object)

# %%
df["Originated From"]=label_encoder.fit_transform(df["Originated From"])
df["Originated From"].unique()
# Out:
# array([ 1, 27, 28,  8,  2, 25, 20,  7, 31,  9, 10, 18, 36, 17, 33, 22, 23,
#        14,  3, 13, 21, 11,  5, 32, 26, 12,  4, 35, 16, 30,  6,  0, 15, 34,
#        29, 19, 24])

# %%
df
# Out:
#     Food  Nutrition Value (per 100g)  Quantity  Originated From  Calories  \
# 0     47                          54         3                1        49
# 1     10                          26         1               27        84
# 2     78                          68        33               28       208
# 3     39                           2         0                8         4
# 4     82                          34         8                2        23
# ..   ...                         ...       ...              ...       ...
# 93    70                          48         9               33        72
# 94    73                          58        11               20         9
# 95    46                          22        12               24        46
# 96    92                          33         8               21         5
# 97    32                          12         6                9       136
#
#     Protein (g)  Fiber (g)  Vitamin C (mg)  Antioxidant Score
# ...

# %%
x=df.drop(["Food"],axis=1)
x
# Out:
#     Nutrition Value (per 100g)  Quantity  Originated From  Calories  \
# 0                           54         3                1        49
# 1                           26         1               27        84
# 2                           68        33               28       208
# 3                            2         0                8         4
# 4                           34         8                2        23
# ..                         ...       ...              ...       ...
# 93                          48         9               33        72
# 94                          58        11               20         9
# 95                          22        12               24        46
# 96                          33         8               21         5
# 97                          12         6                9       136
#
#     Protein (g)  Fiber (g)  Vitamin C (mg)  Antioxidant Score
# 0           4.3        3.6            93.4               1770
# ...

# %%
y=df["Food"]
y
# Out:
# 0     47
# 1     10
# 2     78
# 3     39
# 4     82
#       ..
# 93    70
# 94    73
# 95    46
# 96    92
# 97    32
# Name: Food, Length: 98, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=80)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_hat=model.predict(x_test)

# %%
model.score(x,y)
# Out:
# 0.06600712700322975

# %%
from sklearn.metrics import r2_score
score=r2_score(y_hat,y_test)

# %%
score
# Out:
# -4.361784234257525
